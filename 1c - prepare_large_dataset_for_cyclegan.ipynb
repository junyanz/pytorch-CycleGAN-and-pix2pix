# %% [markdown]
# # Data Preparation for the Physformer-CycleGAN

# %% [markdown]
# First of all fuck meme coins actually

# %% [markdown]
# From the repositiory structure, it looks like we have to place the pngs or jpegs in trainA and trainB
# So we if break it down, we need real world and physcial dataset train and test split that can be reproduce and then can be automatically placed in the corresponding folders.

# %%
import os
import numpy as np
import json
import pickle
import matplotlib.pyplot as plt
import pandas as pd 
from PIL import Image
np.random.seed(42)

# %% [markdown]
# # Saving the Source Data properly into the CycleGan Repo

# %%
def preprocess_image(img):
    img = img.astype(np.float32)
    img = (img - np.min(img)) / (np.max(img) - np.min(img))
    # intesnity correction and multiplying it with the 255
    # img = img**1.5 
    img = img*255
    img = img.astype(np.uint8)
    return img

# At first, we locaate all the npz files of the physcial dataset and then decode them into pngs
# then we need to split the data into train and test set
# then we copy the BUSI train and test images similarly in the folder. 
# Then we move this folder outside to the data folder to avoid the memory issues. 

# new physcial datase path for npz files are where
# lets think about the train and test split for the 
# Lets read the npz files 
# FOLD_ID = 4
# source_npz_files = np.load(f"/home/user/data/phyusformer_data/all_combined_synthetic_datasets_V3_BM/data_npz/train_val_test_data_biased_fold_{FOLD_ID}.npz")
# source_train_arrays = source_npz_files['X_train']
# source_val_arrays = source_npz_files['X_val']
# source_test_arrays = source_npz_files['X_test']

# # load the json for proper indexing  of the images
# # split was made after the Op BM when i was trainign a large seformer 
# json_path = "/home/user/data/phyusformer_data/all_combined_synthetic_datasets_V3_BM/data_npz/biased_cv_folds.json"
# with open(json_path,"r") as f:
#     split_info = json.load(f)[FOLD_ID]


# train_indices = split_info['train_indices'] 
# val_indices = split_info['val_indices']
# test_indices = split_info['test_indices']



dataset_name = "synt2realUS_cyclegan"
images_save_dir = f"/home/user/data/phyusformer_data/style_transfer/{dataset_name}"

source_train_images_save_path = os.path.join(images_save_dir,"trainA")
source_test_images_save_path = os.path.join(images_save_dir,"testA")
os.makedirs(source_train_images_save_path,exist_ok=True)
os.makedirs(source_test_images_save_path,exist_ok=True)

# print(source_test_images_save_path)

for idx, img in enumerate(source_train_arrays):
    img = img.squeeze(0) # optional: does not work with every data modality
    img = preprocess_image(img)
    img = Image.fromarray(img)
    img_id = train_indices[idx]
    # lets write the image without any axis, labels, ticks for the cyclegan to use
    img.save(os.path.join(source_train_images_save_path,f"img_{img_id}.jpg"))
    # break

for idx, img in enumerate(source_val_arrays):
    img = img.squeeze(0)
    img = preprocess_image(img)
    img = Image.fromarray(img)
    img_id = val_indices[idx]
    img.save(os.path.join(source_train_images_save_path,f"img_{img_id}.jpg"))
    # break

for idx, img in enumerate(source_test_arrays):
    img = img.squeeze(0)
    img = preprocess_image(img)
    img = Image.fromarray(img)
    img_id = test_indices[idx]
    # lets write the image without any axis, labels, ticks for the cyclegan to use
    img.save(os.path.join(source_test_images_save_path,f"img_{img_id}.jpg"))
    # break

# # Lets see the images in the trainA folder
images_train_source = os.listdir(source_train_images_save_path)
images_test_source = os.listdir(source_test_images_save_path)
# # images_train_source = [int(img.split(".")[0].split("_")[1]) for img in images_train_source]
print("Number of images in the trainA folder", len(images_train_source))
print("Number of images in the testA folder", len(images_test_source))
# Out:
# Number of images in the trainA folder 8319
# Number of images in the testA folder 924

# %% [markdown]
# # Lets get the training and testing images from the BUSI folder and save their images into the folder

# %%
dataset_name = "synt2realUS_cyclegan"
images_save_dir = f"/home/user/data/phyusformer_data/style_transfer/{dataset_name}"

target_train_images_save_path = os.path.join(images_save_dir,"trainB")
target_test_images_save_path = os.path.join(images_save_dir,"testB")
os.makedirs(target_train_images_save_path,exist_ok=True)
os.makedirs(target_test_images_save_path,exist_ok=True)

# %%
# BUSI dataset path 

benign_images_path = "/home/user/data/phyusformer_data/post_miccai_exps/data/data_busi/Dataset_BUSI_with_GT/benign"
malignant_images_path = "/home/user/data/phyusformer_data/post_miccai_exps/data/data_busi/Dataset_BUSI_with_GT/malignant"
# BUSI dataset 
benign_images = os.listdir(benign_images_path)
malignant_images = os.listdir(malignant_images_path)
# all_busi_images = benign_images + malignant_images
source_data = "busi"
all_busi_images_paths = [(os.path.join(benign_images_path,img),source_data) for img in benign_images if not "mask" in img] + [(os.path.join(malignant_images_path,img),source_data) for img in malignant_images if not "mask" in img]

# Loading the Breast-stu paths 
root_path_breast_stu = "/home/user/data/phyusformer_data/post_miccai_exps/data/US30k/US30K/Breast-STU/img"
source_data = "breast_stu"
all_breast_stu_images_paths = [(os.path.join(root_path_breast_stu,img),source_data) for img in os.listdir(root_path_breast_stu)]
print(len(all_breast_stu_images_paths))
print(all_breast_stu_images_paths[0])
# Loading Breast-UDIAT paths
source_data = "breast_udiat"
root_path_breast_udiat = "/home/user/data/phyusformer_data/post_miccai_exps/data/US30k/US30K/Breast-UDIAT/img"
all_breast_udiat_images_paths = [(os.path.join(root_path_breast_udiat,img),source_data) for img in os.listdir(root_path_breast_udiat)]
print(len(all_breast_udiat_images_paths))
print(all_breast_udiat_images_paths[0])
# Loading TN3k datasets : Pagal kuttay nay kaata tha iss liye load kia hai issay 
source_data = "tn3k"
root_path_tn3k = "/home/user/data/phyusformer_data/post_miccai_exps/data/US30k/US30K/ThyroidNodule-TN3K/img"
all_tn3k_images_paths = [(os.path.join(root_path_tn3k,img),source_data) for img in os.listdir(root_path_tn3k)]
print(len(all_tn3k_images_paths))
print(all_tn3k_images_paths[0])


# combine all target datasets 
all_target_datasets_paths = all_busi_images_paths + all_breast_stu_images_paths + all_breast_udiat_images_paths + all_tn3k_images_paths
print(len(all_target_datasets_paths))
print(all_target_datasets_paths[0])
# Out:
# 42
# ('/home/user/data/phyusformer_data/post_miccai_exps/data/US30k/US30K/Breast-STU/img/5.png', 'breast_stu')
# 163
# ('/home/user/data/phyusformer_data/post_miccai_exps/data/US30k/US30K/Breast-UDIAT/img/000067.png', 'breast_udiat')
# 3493
# ('/home/user/data/phyusformer_data/post_miccai_exps/data/US30k/US30K/ThyroidNodule-TN3K/img/trainval2754.png', 'tn3k')
# 4345
# ('/home/user/data/phyusformer_data/post_miccai_exps/data/data_busi/Dataset_BUSI_with_GT/benign/benign (342).png', 'busi')

# %%
# np.random.seed(42)
# df = pd.DataFrame({"image_path":list(map(lambda x: x[0],all_target_datasets_paths))})
# df['source_data'] = list(map(lambda x: x[1],all_target_datasets_paths))
# df['image_key'] = df['image_path'].apply(lambda x: x.split("/")[-1].split(".")[0])
# df['image_id'] = df.apply(lambda x: x['source_data'] + "_" + x['image_key'],axis=1)
# df['image_type'] = df['image_path'].apply(lambda x: x.split("/")[-1].split(".")[1])
# df.to_csv("large_ultrasound_target_images_info.csv",index=False)
# df.drop_duplicates(subset="image_key",inplace=True,keep="first")
# df.sort_values(by="image_key",inplace=True)
# df.to_csv("large_ultrasound_target_images_info.csv",index=False)
# # # Randomly pick the train and test split test
# train_indices = np.random.choice(df.index,size=int(len(df)*0.8),replace=False)
# test_indices = np.setdiff1d(df.index,train_indices)
# df.loc[train_indices,"split"] = "train"
# df.loc[test_indices,"split"] = "test"
# df.to_csv("datasets/large_ultrasound_target_images_split_info.csv",index=False)

# %%
import shutil
# Lets call each image path and save it in the trainB and testB folder
for idx,row in df.iterrows():
    if row["split"] == "train":
        # print(row["image_path"])
        shutil.copy(row["image_path"],os.path.join(target_train_images_save_path,f"img_{row['image_id']}.{row['image_type']}"))
    else:
        # print(row["image_path"])
        shutil.copy(row["image_path"],os.path.join(target_test_images_save_path,f"img_{row['image_id']}.{row['image_type']}"))
    # break

# %%
# prin the length of the train and test images
print(len(os.listdir(target_train_images_save_path)))
print(len(os.listdir(target_test_images_save_path)))
# Out:
# 3476
# 869

# %%
import cv2

# %%
cv2.imread(os.path.join(target_train_images_save_path,os.listdir(target_train_images_save_path)[0])).shape
# Out:
# (463, 557, 3)
