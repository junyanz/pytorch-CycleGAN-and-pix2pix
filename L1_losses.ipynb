# %% [markdown]
# Based on https://github.com/sebasmos/vcg/blob/main/Training_Plot_With_Loss/Plotting_Loss.ipynb

# %%
import pickle
with open('loss.pkl', 'rb') as f:
    Loss_per_epoch = pickle.load(f)
Loss_per_epoch
# Out:
# [[16.717078557784145,
#   15.602260177889207,
#   10.6945653877149,
#   11.567342705348615,
#   8.208999298591213,
#   10.363966802471346,
#   10.321373007700574,
#   16.560037607449857,
#   7.206312585810649,
#   10.621919211138968,
#   15.42128924904489,
#   14.414013065604108,
#   9.728709631685769,
#   12.817276481912607,
#   17.76923091272684,
#   10.877092100943171,
#   11.688964377387775,
#   19.155843332139447,
#   15.37726372224212,
#   1],
#  [16.599090780205348,
#   15.423841183142311,
#   10.718124141893504,
#   11.662534697349571,
#   8.010049173233046,
#   10.348769922994268,
#   10.384313253641356,
#   17.170804232330468,
#   7.026254794203677,
#   10.66524612732808,
#   15.575273661353869,
#   14.48306545487106,
#   9.741806948424069,
#   12.956728114553487,
#   18.255969436485195,
#   10.980598398698662,
#   11.491206273877745,
#   19.855834377984717,
#   15.269252365389207,
#   2],
#  [16.679318141117477,
#   15.415370801496339,
#   10.994271828239414,
#   11.552508655682903,
#   7.588917243712194,
#   10.492262117956065,
#   10.442898609121299,
#   19.890825224848776,
#   6.821931709646609,
#   10.639749482648838,
#   15.825500935211716,
#   14.155400598933461,
#   10.085481086835403,
#   12.710864125676537,
#   17.91361354863101,
#   11.109115080786374,
#   11.12708059734161,
#   19.39495284145177,
#   15.409597858962114,
#   3]]

# %%
len(Loss_per_epoch)
# Out:
# 3

# %%
len(Loss_per_epoch[0])
# Out:
# 20

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df = pd.DataFrame(Loss_per_epoch)
df
# Out:
#           0          1          2          3         4          5          6   \
# 0  16.717079  15.602260  10.694565  11.567343  8.208999  10.363967  10.321373
# 1  16.599091  15.423841  10.718124  11.662535  8.010049  10.348770  10.384313
# 2  16.679318  15.415371  10.994272  11.552509  7.588917  10.492262  10.442899
#
#           7         8          9          10         11         12         13  \
# 0  16.560038  7.206313  10.621919  15.421289  14.414013   9.728710  12.817276
# 1  17.170804  7.026255  10.665246  15.575274  14.483065   9.741807  12.956728
# 2  19.890825  6.821932  10.639749  15.825501  14.155401  10.085481  12.710864
#
#           14         15         16         17         18  19
# 0  17.769231  10.877092  11.688964  19.155843  15.377264   1
# 1  18.255969  10.980598  11.491206  19.855834  15.269252   2
# 2  17.913614  11.109115  11.127081  19.394953  15.409598   3

# %%
df.iloc[:,:19]
# Out:
#           0          1          2          3         4          5          6   \
# 0  16.717079  15.602260  10.694565  11.567343  8.208999  10.363967  10.321373
# 1  16.599091  15.423841  10.718124  11.662535  8.010049  10.348770  10.384313
# 2  16.679318  15.415371  10.994272  11.552509  7.588917  10.492262  10.442899
#
#           7         8          9          10         11         12         13  \
# 0  16.560038  7.206313  10.621919  15.421289  14.414013   9.728710  12.817276
# 1  17.170804  7.026255  10.665246  15.575274  14.483065   9.741807  12.956728
# 2  19.890825  6.821932  10.639749  15.825501  14.155401  10.085481  12.710864
#
#           14         15         16         17         18
# 0  17.769231  10.877092  11.688964  19.155843  15.377264
# 1  18.255969  10.980598  11.491206  19.855834  15.269252
# 2  17.913614  11.109115  11.127081  19.394953  15.409598

# %%
import seaborn as sns
palette = sns.color_palette("husl", 19) # https://seaborn.pydata.org/generated/seaborn.color_palette.html
fig = plt.figure('fig_size', (15, 15))
# Adding grid
sns.set(style="ticks")
#sns.set_style("darkgrid")#whitegrid")# #https://seaborn.pydata.org/generated/seaborn.set_style.html
sns.lineplot(data=df.iloc[:,:19], markers=True, dashes=False, palette=palette,legend="full")
plt.title("L1 per channel")
plt.ylabel("Loss")
plt.xlabel("Epochs")
plt.grid()
plt.show()
plt.close('all')

# %%
import seaborn as sns
palette = sns.color_palette("husl", 19) # https://seaborn.pydata.org/generated/seaborn.color_palette.html
fig = plt.figure('fig_size', (15, 15))
# Adding grid
sns.set(style="ticks")
sns.set_style("darkgrid")#whitegrid")# #https://seaborn.pydata.org/generated/seaborn.set_style.html
sns.lineplot(data=df.iloc[:,:19], markers=True, dashes=False, palette=palette,legend="full")
plt.title("L1 per channel")
plt.ylabel("Loss")
plt.xlabel("Epochs")
#plt.grid()
plt.show()
plt.close('all')
