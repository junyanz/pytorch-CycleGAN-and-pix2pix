# %% [markdown]
# Based on https://github.com/sebasmos/vcg/blob/main/Training_Plot_With_Loss/Plotting_Loss.ipynb

# %%
import pickle
with open('loss_CRC04.pkl', 'rb') as f:
    Loss_per_epoch = pickle.load(f)

# %%
len(Loss_per_epoch)
# Out:
# 270

# %%
len(Loss_per_epoch[0])
# Out:
# 20

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df = pd.DataFrame(Loss_per_epoch)
df
# Out:
#             0          1          2          3         4          5   \
# 0    16.115535  15.564445  10.661172  11.478852  7.928051  10.303394
# 1    16.180628  15.474039  10.705682  11.410634  7.673374  10.299877
# 2    16.042486  15.407584  10.670097  11.307373  7.529497  10.503376
# 3    16.017158  15.315822  10.537589  11.219322  7.406029  10.646509
# 4    15.962961  15.244877  10.457390  11.149261  7.319636  10.724793
# ..         ...        ...        ...        ...       ...        ...
# 265  14.761816  13.202738   9.216919  10.406148  6.937515  11.554941
# 266  14.754789  13.191871   9.208389  10.399975  6.934931  11.553685
# 267  14.748540  13.181482   9.200186  10.394180  6.932224  11.552810
# 268  14.742577  13.171151   9.192010  10.388315  6.929587  11.551905
# 269  14.736016  13.160538   9.183708  10.382488  6.926791  11.550889
#
#             6          7         8          9          10         11  \
# 0    10.265554  16.569191  6.966402  10.554216  15.245934  14.237905
# 1    10.258641  17.245706  6.839960  10.526995  15.402282  14.254861
# 2    10.237731  17.890473  6.679327  10.466479  15.487400  14.243375
# 3    10.196094  18.208393  6.546885  10.403212  15.520346  14.194279
# 4    10.145665  18.476588  6.437199  10.331123  15.586264  14.103967
# ..         ...        ...       ...        ...        ...        ...
# 265   9.915836  15.375667  6.170132   9.633296  15.017056  13.088784
# 266   9.911511  15.354950  6.167749   9.628402  15.003987  13.083003
# 267   9.907246  15.334272  6.165358   9.623861  14.991035  13.077880
# 268   9.903057  15.313361  6.163032   9.619194  14.978224  13.072628
# 269   9.898847  15.292893  6.160597   9.614453  14.965032  13.067199
#
#            12         13         14         15         16         17  \
# 0    9.606043  12.692844  17.523499  10.810955  11.314427  18.902314
# 1    9.543707  12.799027  17.868210  11.004127  11.143385  19.293155
# 2    9.513288  12.823701  18.053531  11.029692  10.941856  19.587238
# 3    9.447156  12.759169  18.071652  10.942103  10.786695  19.632928
# 4    9.379657  12.698560  18.086609  10.886711  10.673696  19.676060
# ..        ...        ...        ...        ...        ...        ...
# 265  9.264492  10.970322  15.694227   9.710792   9.625154  16.559989
# 266  9.261875  10.961162  15.682018   9.705223   9.617411  16.543677
# 267  9.259213  10.952066  15.669953   9.699961   9.609920  16.528033
# 268  9.256796  10.942947  15.657849   9.694723   9.602216  16.512450
# 269  9.254138  10.933818  15.645599   9.689407   9.594480  16.496792
#
#             18   19
# 0    15.280003    1
# 1    15.151224    2
# 2    15.115562    3
# 3    15.073241    4
# 4    15.076012    5
# ..         ...  ...
# 265  13.940462  266
# 266  13.927943  267
# 267  13.915546  268
# 268  13.903630  269
# 269  13.891570  270
#
# [270 rows x 20 columns]

# %%
n_ch= len(df.columns)

# %%
df.iloc[:,:n_ch]
# Out:
#             0          1          2          3         4          5   \
# 0    16.115535  15.564445  10.661172  11.478852  7.928051  10.303394
# 1    16.180628  15.474039  10.705682  11.410634  7.673374  10.299877
# 2    16.042486  15.407584  10.670097  11.307373  7.529497  10.503376
# 3    16.017158  15.315822  10.537589  11.219322  7.406029  10.646509
# 4    15.962961  15.244877  10.457390  11.149261  7.319636  10.724793
# ..         ...        ...        ...        ...       ...        ...
# 265  14.761816  13.202738   9.216919  10.406148  6.937515  11.554941
# 266  14.754789  13.191871   9.208389  10.399975  6.934931  11.553685
# 267  14.748540  13.181482   9.200186  10.394180  6.932224  11.552810
# 268  14.742577  13.171151   9.192010  10.388315  6.929587  11.551905
# 269  14.736016  13.160538   9.183708  10.382488  6.926791  11.550889
#
#             6          7         8          9          10         11  \
# 0    10.265554  16.569191  6.966402  10.554216  15.245934  14.237905
# 1    10.258641  17.245706  6.839960  10.526995  15.402282  14.254861
# 2    10.237731  17.890473  6.679327  10.466479  15.487400  14.243375
# 3    10.196094  18.208393  6.546885  10.403212  15.520346  14.194279
# 4    10.145665  18.476588  6.437199  10.331123  15.586264  14.103967
# ..         ...        ...       ...        ...        ...        ...
# 265   9.915836  15.375667  6.170132   9.633296  15.017056  13.088784
# 266   9.911511  15.354950  6.167749   9.628402  15.003987  13.083003
# 267   9.907246  15.334272  6.165358   9.623861  14.991035  13.077880
# 268   9.903057  15.313361  6.163032   9.619194  14.978224  13.072628
# 269   9.898847  15.292893  6.160597   9.614453  14.965032  13.067199
#
#            12         13         14         15         16         17  \
# 0    9.606043  12.692844  17.523499  10.810955  11.314427  18.902314
# 1    9.543707  12.799027  17.868210  11.004127  11.143385  19.293155
# 2    9.513288  12.823701  18.053531  11.029692  10.941856  19.587238
# 3    9.447156  12.759169  18.071652  10.942103  10.786695  19.632928
# 4    9.379657  12.698560  18.086609  10.886711  10.673696  19.676060
# ..        ...        ...        ...        ...        ...        ...
# 265  9.264492  10.970322  15.694227   9.710792   9.625154  16.559989
# 266  9.261875  10.961162  15.682018   9.705223   9.617411  16.543677
# 267  9.259213  10.952066  15.669953   9.699961   9.609920  16.528033
# 268  9.256796  10.942947  15.657849   9.694723   9.602216  16.512450
# 269  9.254138  10.933818  15.645599   9.689407   9.594480  16.496792
#
#             18   19
# 0    15.280003    1
# 1    15.151224    2
# 2    15.115562    3
# 3    15.073241    4
# 4    15.076012    5
# ..         ...  ...
# 265  13.940462  266
# 266  13.927943  267
# 267  13.915546  268
# 268  13.903630  269
# 269  13.891570  270
#
# [270 rows x 20 columns]

# %%
n_ch
# Out:
# 20

# %%
import seaborn as sns
palette = sns.color_palette("husl", (n_ch-1)) # https://seaborn.pydata.org/generated/seaborn.color_palette.html
fig = plt.figure('fig_size', (10, 10))
# Adding grid
sns.set(style="ticks")
#sns.set_style("darkgrid")#whitegrid")# #https://seaborn.pydata.org/generated/seaborn.set_style.html
sns.lineplot(data=df.iloc[:,:n_ch-1], 
             markers=True, 
             dashes=False, 
             palette=palette, 
             linewidth = 5)

plt.legend(loc='lower right')
plt.title("L1 per channel - L1{Fake_IF, Real_IF}")
plt.ylabel("Loss")
plt.xlabel("Epochs")
plt.grid()
plt.show()
plt.close('all')

# %%
import seaborn as sns
palette = sns.color_palette("husl", n_ch-1) # https://seaborn.pydata.org/generated/seaborn.color_palette.html
fig = plt.figure('fig_size', (10, 10))
# Adding grid
sns.set(style="ticks")
sns.set_style("darkgrid")#whitegrid")# #https://seaborn.pydata.org/generated/seaborn.set_style.html
sns.lineplot(data=df.iloc[:,:n_ch-1], 
             markers=True, 
             dashes=False, 
             palette=palette, 
             linewidth = 5)

plt.title("L1 per channel - L1{Fake_IF, Real_IF}")
plt.axhline(y=17.5 , color='red', linestyle='--', label="Limit")
plt.legend(loc='lower right')
plt.ylabel("Loss")
plt.xlabel("Epochs")
#plt.grid()
plt.savefig("loss1.png", bbox_inches='tight', pad_inches=0)#, dpi = 64)
plt.show()
plt.close('all')

# %%
import seaborn as sns
channels = [17,7, 14]
palette = sns.color_palette("husl", len(channels)) # https://seaborn.pydata.org/generated/seaborn.color_palette.html
fig = plt.figure('fig_size', (5, 5))
# Adding grid
sns.set(style="ticks")
sns.set_style("darkgrid")#whitegrid")# #https://seaborn.pydata.org/generated/seaborn.set_style.html
sns.lineplot(data=df.iloc[:,channels], 
             markers=True, 
             dashes=False, 
             palette=palette, 
             linewidth = 2)

plt.axhline(y=17.5 , color='red', linestyle='--', label="Limit")
plt.legend(loc='lower right')
plt.title("L1 per channel - L1{Fake_IF, Real_IF}")
plt.ylabel("Loss")
plt.xlabel("Epochs")
#plt.grid()
plt.savefig("loss1.png", bbox_inches='tight', pad_inches=0)#, dpi = 64)
plt.show()
plt.close('all')

# %%
import seaborn as sns
channels = [0,1,2,3,4,5,6,8,9,10,11,12,13,15,16,18]
palette = sns.color_palette("husl", len(channels)) # https://seaborn.pydata.org/generated/seaborn.color_palette.html
fig = plt.figure('fig_size', (10, 10))
# Adding grid
sns.set(style="ticks")
sns.set_style("darkgrid")#whitegrid")# #https://seaborn.pydata.org/generated/seaborn.set_style.html
sns.lineplot(data=df.iloc[:,channels], 
             markers=True, 
             dashes=False, 
             palette=palette, 
             linewidth = 2)

plt.axhline(y=17.5 , color='red', linestyle='--', label="Limit")
plt.legend(loc='lower right')
plt.title("L1 per channel - L1{Fake_IF, Real_IF}")
plt.ylabel("Loss")
plt.xlabel("Epochs")
#plt.grid()
plt.savefig("loss1.png", bbox_inches='tight', pad_inches=0)#, dpi = 64)
plt.show()
plt.close('all')

# %%
import seaborn as sns
channels = [0,3,17,18]
palette = sns.color_palette("husl", len(channels)) # https://seaborn.pydata.org/generated/seaborn.color_palette.html
fig = plt.figure('fig_size', (5, 5))
# Adding grid
sns.set(style="ticks")
sns.set_style("darkgrid")#whitegrid")# #https://seaborn.pydata.org/generated/seaborn.set_style.html
sns.lineplot(data=df.iloc[:,channels], 
             markers=True, 
             dashes=False, 
             palette=palette, 
             linewidth = 2)
plt.axhline(y=17.5 , color='red', linestyle='--', label="Limit")
plt.legend(loc='lower right')
plt.title("L1 per channel")
plt.ylabel("Loss")
plt.xlabel("Epochs")
#plt.grid()
plt.savefig("loss1.png", bbox_inches='tight', pad_inches=0)#, dpi = 64)
plt.show()
plt.close('all')

# %% [markdown]
# ### Legend locations
# ```
# upper right
# upper left
# lower left
# lower right
# right
# center left
# center right
# lower center
# upper center
# center
# ```
